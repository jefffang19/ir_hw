# %%
import json

# read a json file from path
def json_reader(path):
    input_file = open(path,'r')
    input_raw = input_file.read()
    input_json = json.loads(input_raw)
    
    return input_json

# %%
# parse a json file and store as a array (len = number of articles)
# the element of array looks like
# { 'sentence' : 'I like apple',
#   'words' : ['I', 'like', 'apple']}
def json_parser(json_dict):
    result = []

    for i in json_dict:
        sentence = []
        for c in i['tweet_text']:
            if(c.isascii()):
                sentence.append(c)
                
        sentence = ''.join(sentence)
        
        element = {}
        words = []
        element['sentence'] = sentence
        for j in sentence.split():
            words.append(j)
        element['words'] = words
        
        result.append(element)
    
    return result

# %%
def remove_puncuation(word_list):
    import string
    
    en_titles = ['Mr.', 'Mrs.', 'Dr.', 'Prof.','Hon.']

    for i in range(len(word_list)):
        if word_list[i] in en_titles:
            continue
        elif len(word_list[i])==2 and word_list[i][0].isupper():
            continue
        else:
            for j in string.punctuation:
                word_list[i] = word_list[i].replace(j, '')
       
    # remove blank string from the list
    word_list = [i for i in word_list if i != ""]
    
    return word_list

# %%
def words_to_lower(word_list):
    return [i.lower() for i in word_list]

# %%
def remove_stopords(word_list, stopword_path = 'stop_words.txt'):
    f = open(stopword_path)
    stop_words = f.read().split('\n')
    # now we create a new word set without the stop words
    words = [word_list[i] for i in range(len(word_list)) if word_list[i] not in stop_words]
    
    return words

# %%
def stemming(word_list):
    from nltk.stem import PorterStemmer 

    ps = PorterStemmer() 

    for i in range(len(word_list)):
        word_list[i] = ps.stem(word_list[i])
        
    return word_list

# %%
# mode = 'json' or 'xml'
def data_processor(input_path, mode = 'json'):
    if(mode == 'json'):
        raw_json = json_reader(input_path)
        articles = json_parser(raw_json)
        for i in articles:
            # process words list
            i['words'] = stemming(remove_stopords(words_to_lower(remove_puncuation(i['words']))))
        
        return articles

# %%
# testing
data_processor('mydata.json')
# Out:
# [{'sentence': '"Introducing Elucis', 'words': ['introduc', 'eluci']},
#  {'sentence': '"Top 12 Python Libraries for Machine Learning and Data Science in 2020 https',
#   'words': ['top',
#    '12',
#    'python',
#    'librari',
#    'machin',
#    'learn',
#    'data',
#    'scienc',
#    '2020',
#    'http']},
#  {'sentence': '"#Deep Learning Optimized Sparse Antenna Activation for Reconfigurable Intelligent Surface Assisted Communication. (arXiv',
#   'words': ['deep',
#    'learn',
#    'optim',
#    'spars',
#    'antenna',
#    'activ',
#    'reconfigur',
#    'intellig',
#    'surfac',
#    'assist',
#    'commun',
#    'arxiv']},
#  {'sentence': '"Complete #Python #Developer in 2020',
#   'words': ['complet', 'python', 'develop', '2020']},
#  {'sentence': '"Neural Network which can detect numbers in python.\nhttps',
#   'words': ['neural', 'network', 'detect', 'number', 'python', 'http']},
#  {'sentence': '"Improving on Naive Bayes with Support Vector Machines #data #science #machine #learning https',
#   'words': ['improv',
#    'naiv',
#    'bay',
#    'support',
#    'vector',
#    'machin',
#    'data',
#    'scienc',
#    'machin',
#    'learn',
#    'http']},
#  {'sentence': '"Let us assist with your due #finals\n#exams\n#Python\n#C #programming\n#java\n#javascript\n#history\n#android\n#artificial #intelligence\n#machine #learning\n#data #visualization\n#data #analytics\n#cost and #F.A #Accounting \n#finance\n#C #sharp\n#python\n#data #structures\nDM for class help"',
#   'words': ['let',
#    'us',
#    'assist',
#    'due',
#    'final',
#    'exam',
#    'python',
#    'c',
#    'program',
#    'java',
#    'javascript',
#    'histori',
#    'android',
#    'artifici',
#    'intellig',
#    'machin',
#    'learn',
#    'data',
#    'visual',
#    'data',
#    'analyt',
#    'cost',
#    'fa',
#    'account',
#    'financ',
#    'c',
#    'sharp',
#    'python',
#    'data',
#    'structur',
#    'dm',
#    'class',
#    'help']},
#  {'sentence': '"#AWS launches #Amazon Kendra, #Machine #learning based #Search Service\nhttps',
#   'words': ['aw',
#    'launch',
#    'amazon',
#    'kendra',
#    'machin',
#    'learn',
#    'base',
#    'search',
#    'servic',
#    'http']},
#  {'sentence': '"Curious how #AI or #machine learning can help solve complex public problems? So are we! \nHead over to our website (https',
#   'words': ['curiou',
#    'ai',
#    'machin',
#    'learn',
#    'help',
#    'solv',
#    'complex',
#    'public',
#    'problem',
#    'head',
#    'websit',
#    'http']},
#  {'sentence': '"How To Develop a Machine Learning Model https',
#   'words': ['develop', 'machin', 'learn', 'model', 'http']},
#  {'sentence': '"#FEATURED #COURSES\n\n#Machine #Learning A-Z',
#   'words': ['featur', 'cours', 'machin', 'learn', 'az']},
#  {'sentence': '"HOW to Classify #Animal Images via ,,, Neural #Network https',
#   'words': ['classifi', 'anim', 'imag', 'via', 'neural', 'network', 'http']},
#  {'sentence': '"Machine Learning and Signal Processing\n\n#machinelearning #Machine #Learning #fft\nhttps',
#   'words': ['machin',
#    'learn',
#    'signal',
#    'process',
#    'machinelearn',
#    'machin',
#    'learn',
#    'fft',
#    'http']},
#  {'sentence': '"Happy to say that I\'ll be working more closely with @NVIDIAEmbedded to build more intelligent robotics projects by adding their Jetson range of computing platforms. What Machine Learning projects would you like to see me attempt?\n\n#ad #robotics #machine #ML #jetson #ai https',
#   'words': ['happi',
#    'say',
#    'ill',
#    'work',
#    'close',
#    'nvidiaembed',
#    'build',
#    'intellig',
#    'robot',
#    'project',
#    'ad',
#    'jetson',
#    'rang',
#    'comput',
#    'platform',
#    'machin',
#    'learn',
#    'project',
#    'would',
#    'like',
#    'see',
#    'attempt',
#    'ad',
#    'robot',
#    'machin',
#    'ml',
#    'jetson',
#    'ai',
#    'http']},
#  {'sentence': '"A very simple and useful guide to run decision tree models using #rstats \n\n#machine #learning #DataScience\n#models \n\nhttps',
#   'words': ['simpl',
#    'use',
#    'guid',
#    'run',
#    'decis',
#    'tree',
#    'model',
#    'use',
#    'rstat',
#    'machin',
#    'learn',
#    'datasci',
#    'model',
#    'http']},
#  {'sentence': '"Optimize ML model with optuna and visualize the result with MLFlow #informatics #machinelearning https',
#   'words': ['optim',
#    'ml',
#    'model',
#    'optuna',
#    'visual',
#    'result',
#    'mlflow',
#    'informat',
#    'machinelearn',
#    'http']},
#  {'sentence': '"Machine Learning A-Z', 'words': ['machin', 'learn', 'az']},
#  {'sentence': '"https', 'words': ['http']},
#  {'sentence': '"#Machine Learning the Nuclear World. \n\n#BigData #Analytics #DataScience #AI #IoT #IIoT #Python #RStats #TensorFlow #Java #JavaScript #ReactJS #CloudComputing #Serverless #DataScientist #Linux #Mathematics #Programming #Coding #100DaysofCode \nhttps',
#   'words': ['machin',
#    'learn',
#    'nuclear',
#    'world',
#    'bigdata',
#    'analyt',
#    'datasci',
#    'ai',
#    'iot',
#    'iiot',
#    'python',
#    'rstat',
#    'tensorflow',
#    'java',
#    'javascript',
#    'reactj',
#    'cloudcomput',
#    'serverless',
#    'datascientist',
#    'linux',
#    'mathemat',
#    'program',
#    'code',
#    '100daysofcod',
#    'http']},
#  {'sentence': '"Decision Trees for Classification #data #science #machine #learning https',
#   'words': ['decis',
#    'tree',
#    'classif',
#    'data',
#    'scienc',
#    'machin',
#    'learn',
#    'http']},
#  {'sentence': '"Self-calibrated #ventilator',
#   'words': ['selfcalibr', 'ventil']},
#  {'sentence': '"How to use PReLU with Keras?  #keras #prelu #relu #activationfunction #activation #function #neuralnetwork #neural #network #deeplearning #machinelearning #tensorflow #datascience #python #ml \n\nhttps',
#   'words': ['use',
#    'prelu',
#    'kera',
#    'kera',
#    'prelu',
#    'relu',
#    'activationfunct',
#    'activ',
#    'function',
#    'neuralnetwork',
#    'neural',
#    'network',
#    'deeplearn',
#    'machinelearn',
#    'tensorflow',
#    'datasci',
#    'python',
#    'ml',
#    'http']},
#  {'sentence': '"Dr. Basit Ali @Official_NUST in collab with @SKKU_1398 researched on developing a convolutional #neural #network-based intelligent fault protection strategy for #microgrid protection. #NUSTresearch \n@IEEEorg @IEEEXplore @ieee_pes @CSSIEEE @ComputerSociety\n\nhttps',
#   'words': ['dr',
#    'basit',
#    'ali',
#    'officialnust',
#    'collab',
#    'skku1398',
#    'research',
#    'develop',
#    'convolut',
#    'neural',
#    'networkbas',
#    'intellig',
#    'fault',
#    'protect',
#    'strategi',
#    'microgrid',
#    'protect',
#    'nustresearch',
#    'ieeeorg',
#    'ieeexplor',
#    'ieeep',
#    'cssieee',
#    'computersocieti',
#    'http']},
#  {'sentence': '"Star Labs has created a #neural network called Core R3 that simulates incredibly lifelike human #avatars.\n#AI #ML #futuristic  https',
#   'words': ['star',
#    'lab',
#    'creat',
#    'neural',
#    'network',
#    'call',
#    'core',
#    'r3',
#    'simul',
#    'incred',
#    'lifelik',
#    'human',
#    'avatar',
#    'ai',
#    'ml',
#    'futurist',
#    'http']},
#  {'sentence': '"Learn about incorporating #bias #nodes into your #neural #network.\nhttps',
#   'words': ['learn', 'incorpor', 'bia', 'node', 'neural', 'network', 'http']},
#  {'sentence': '"A #neural #network approach for real-time particle/cell characterization in #microfluidic #impedance #cytometry\nby Nathan S. Swami et al @UVA @UVAEngineers @FederikaCaselli @UTORV @unitorvergata #realtime #processing\n\nhttps',
#   'words': ['neural',
#    'network',
#    'approach',
#    'realtim',
#    'particlecel',
#    'character',
#    'microfluid',
#    'imped',
#    'cytometri',
#    'nathan',
#    's.',
#    'swami',
#    'et',
#    'al',
#    'uva',
#    'uvaengin',
#    'federikacaselli',
#    'utorv',
#    'unitorvergata',
#    'realtim',
#    'process',
#    'http']},
#  {'sentence': '"SCENE', 'words': ['scene']},
#  {'sentence': '"Scientists have enabled the brains natural #neurons to communicate with artificial ones https',
#   'words': ['scientist',
#    'enabl',
#    'brain',
#    'natur',
#    'neuron',
#    'commun',
#    'artifici',
#    'one',
#    'http']},
#  {'sentence': '"Ideas by @kjam to hack #surveillance #capitalism. @transmediale #e2e @KIM_HfG #neural #network #culture "',
#   'words': ['idea',
#    'kjam',
#    'hack',
#    'surveil',
#    'capit',
#    'transmedial',
#    'e2e',
#    'kimhfg',
#    'neural',
#    'network',
#    'cultur']},
#  {'sentence': '"#Socionext #AI #Chip Integrates #Quantized #Deep #Neural #Network #Engine\nhttps',
#   'words': ['socionext',
#    'ai',
#    'chip',
#    'integr',
#    'quantiz',
#    'deep',
#    'neural',
#    'network',
#    'engin',
#    'http']},
#  {'sentence': '"#Creating a #Neural #Network from #Scratch... \n#neuralnet #ml #dl #ai https',
#   'words': ['creat',
#    'neural',
#    'network',
#    'scratch',
#    'neuralnet',
#    'ml',
#    'dl',
#    'ai',
#    'http']},
#  {'sentence': '"The finding establishes #neuromorphic hardware as a fast and scalable avenue to explore the impact of biological plasticity rules on #neural computation and network dynamics.\n\n Read more',
#   'words': ['find',
#    'establish',
#    'neuromorph',
#    'hardwar',
#    'fast',
#    'scalabl',
#    'avenu',
#    'explor',
#    'impact',
#    'biolog',
#    'plastic',
#    'rule',
#    'neural',
#    'comput',
#    'network',
#    'dynam',
#    'read']},
#  {'sentence': '"Happy to share #Neural #Network-Based #Formula for the #Buckling Load #Prediction of I-Section #Cellular #Steel #Beams https',
#   'words': ['happi',
#    'share',
#    'neural',
#    'networkbas',
#    'formula',
#    'buckl',
#    'load',
#    'predict',
#    'isect',
#    'cellular',
#    'steel',
#    'beam',
#    'http']},
#  {'sentence': '"Researchers study why neural networks are efficient in their predictions',
#   'words': ['research', 'studi', 'neural', 'network', 'effici', 'predict']},
#  {'sentence': '"#Astronomy #Artificial #Intelligence #AI #Machine #Learning #ML #Neural #Network #DeepLearning #BigData #DataScience | A Neural Network has re-discovered the Copernican Principle of #HelioCentricity - but cannot predict the outcohttps',
#   'words': ['astronomi',
#    'artifici',
#    'intellig',
#    'ai',
#    'machin',
#    'learn',
#    'ml',
#    'neural',
#    'network',
#    'deeplearn',
#    'bigdata',
#    'datasci',
#    'neural',
#    'network',
#    'rediscov',
#    'copernican',
#    'principl',
#    'heliocentr',
#    'cannot',
#    'predict',
#    'outcohttp']},
#  {'sentence': '"#Neural [#Archive] From #Counterculture to #Cyberculture',
#   'words': ['neural', 'archiv', 'countercultur', 'cybercultur']},
#  {'sentence': '"#Neural [#Archive] THE #ETERNAL #NETWORK - THE ENDS AND BECOMINGS OF NETWORK #CULTURE - Edited by Kristoffer Gansing and Inga Luchs - @INCAmsterdam, @transmediale - https',
#   'words': ['neural',
#    'archiv',
#    'etern',
#    'network',
#    'end',
#    'becom',
#    'network',
#    'cultur',
#    'edit',
#    'kristoff',
#    'gans',
#    'inga',
#    'luch',
#    'incamsterdam',
#    'transmedial',
#    'http']},
#  {'sentence': '"Prof. Qian & Prof. Wu\'s research team published an article in @NatureNano which shows a #neural network integrated with synapse, dendrite & soma, improving network classification accuracy. Full article',
#   'words': ['prof',
#    'qian',
#    'prof.',
#    'wu',
#    'research',
#    'team',
#    'publish',
#    'articl',
#    'naturenano',
#    'show',
#    'neural',
#    'network',
#    'integr',
#    'synaps',
#    'dendrit',
#    'soma',
#    'improv',
#    'network',
#    'classif',
#    'accuraci',
#    'full',
#    'articl']},
#  {'sentence': '"Physicist', 'words': ['physicist']},
#  {'sentence': '" Only a few days left to apply for our Call for Expression of Interest on #neural #network models!\n\n Find out more',
#   'words': ['day',
#    'left',
#    'appli',
#    'call',
#    'express',
#    'interest',
#    'neural',
#    'network',
#    'model',
#    'find']},
#  {'sentence': '"@MicrochipTech launched #Software Development Kit and #Neural #Network IP\nhttps',
#   'words': ['microchiptech',
#    'launch',
#    'softwar',
#    'develop',
#    'kit',
#    'neural',
#    'network',
#    'ip',
#    'http']},
#  {'sentence': '"#NeuroAI seminar now has a webpage with information and list of #ICML and #CVPR papers we are reading in the summer. https',
#   'words': ['neuroai',
#    'seminar',
#    'webpag',
#    'inform',
#    'list',
#    'icml',
#    'cvpr',
#    'paper',
#    'read',
#    'summer',
#    'http']},
#  {'sentence': '"Learning about Conditional Adversarial Networks? Visit this #CVPR paper on the topic. You\'ll find figures and tables, citations as well as videos, code libraries, and news articles discussing its exciting applications and developments. https',
#   'words': ['learn',
#    'condit',
#    'adversari',
#    'network',
#    'visit',
#    'cvpr',
#    'paper',
#    'topic',
#    'youll',
#    'find',
#    'figur',
#    'tabl',
#    'citat',
#    'well',
#    'video',
#    'code',
#    'librari',
#    'news',
#    'articl',
#    'discuss',
#    'excit',
#    'applic',
#    'develop',
#    'http']},
#  {'sentence': '"#CVPR 2020 1/4', 'words': ['cvpr', '2020', '14']},
#  {'sentence': '"Final touches  #CVPR #tarkkaahommaa "',
#   'words': ['final', 'touch', 'cvpr', 'tarkkaahommaa']},
#  {'sentence': '"This goes for all conferences. I complained about the 5 minute #CVPR talks in 2018. Its a cool idea, but researchers dive into the technical weeds so quickly that unless youre intimately familiar with the specific topic, youre lost and start browsing @Twitter on your phone. https',
#   'words': ['goe',
#    'confer',
#    'complain',
#    '5',
#    'minut',
#    'cvpr',
#    'talk',
#    '2018',
#    'cool',
#    'idea',
#    'research',
#    'dive',
#    'technic',
#    'weed',
#    'quickli',
#    'unless',
#    'your',
#    'intim',
#    'familiar',
#    'specif',
#    'topic',
#    'your',
#    'lost',
#    'start',
#    'brows',
#    'twitter',
#    'phone',
#    'http']},
#  {'sentence': '"Best Paper of the Year at CVPR. Read this in-depth article from @analyticsdrift\n\n#cvpr #DataScience #Technology #AI #ML #ArtificialIntelligence #technews #MachineLearning #Python #ml #autoencoder \n https',
#   'words': ['best',
#    'paper',
#    'year',
#    'cvpr',
#    'read',
#    'indepth',
#    'articl',
#    'analyticsdrift',
#    'cvpr',
#    'datasci',
#    'technolog',
#    'ai',
#    'ml',
#    'artificialintellig',
#    'technew',
#    'machinelearn',
#    'python',
#    'ml',
#    'autoencod',
#    'http']},
#  {'sentence': '"Tomorrow(Monday) I will spend my whole day at Minds vs. Machines #CVPR2020 workshops, hopefully, I will learn a bit about my own mind, just kidding , see you there. \nPS. This workshop is open for all zoom link and schedule are posted here',
#   'words': ['tomorrowmonday',
#    'spend',
#    'whole',
#    'day',
#    'mind',
#    'vs',
#    'machin',
#    'cvpr2020',
#    'workshop',
#    'hope',
#    'learn',
#    'bit',
#    'mind',
#    'kid',
#    'see',
#    'ps',
#    'workshop',
#    'open',
#    'zoom',
#    'link',
#    'schedul',
#    'post']},
#  {'sentence': '"Extended abstracts for the #VizWiz workshop at #CVPR are now available online!\n\nSee',
#   'words': ['extend',
#    'abstract',
#    'vizwiz',
#    'workshop',
#    'cvpr',
#    'avail',
#    'onlin',
#    'see']},
#  {'sentence': '"Check out our recent work on counting actions in the wild! Model is learned entirely unsupervised. It successfully transfers to real life video repetitions! Also check out temporal self-similarity layer which is the main secret sauce! #CVPR2020 #CVPR https',
#   'words': ['check',
#    'recent',
#    'work',
#    'count',
#    'action',
#    'wild',
#    'model',
#    'learn',
#    'entir',
#    'unsupervis',
#    'success',
#    'transfer',
#    'real',
#    'life',
#    'video',
#    'repetit',
#    'also',
#    'check',
#    'tempor',
#    'selfsimilar',
#    'layer',
#    'main',
#    'secret',
#    'sauc',
#    'cvpr2020',
#    'cvpr',
#    'http']},
#  {'sentence': '"Join our discussion on \'-nets',
#   'words': ['join', 'discuss', 'net']},
#  {'sentence': '"Congratulations to Shagun Uppal, Anish Madan, Sarthak Bhagat, and @RatnRajiv on getting their poster titled, "Weakly Supervised Categoric Visual Question Generation" accepted at the #CVPR Visual Question Answering and Dialog Workshop. \n\nCheck details at https',
#   'words': ['congratul',
#    'shagun',
#    'uppal',
#    'anish',
#    'madan',
#    'sarthak',
#    'bhagat',
#    'ratnrajiv',
#    'get',
#    'poster',
#    'titl',
#    'weakli',
#    'supervis',
#    'categor',
#    'visual',
#    'question',
#    'gener',
#    'accept',
#    'cvpr',
#    'visual',
#    'question',
#    'answer',
#    'dialog',
#    'workshop',
#    'check',
#    'detail',
#    'http']},
#  {'sentence': '"Work jointly led by @jiasenlu and @vedanujg. In collaboration with Marcus Rohrbach and @stefmlee. \n\nTo appear @cvpr2020 #CVPR #CVPR2020. \n\nhttps',
#   'words': ['work',
#    'jointli',
#    'led',
#    'jiasenlu',
#    'vedanujg',
#    'collabor',
#    'marcu',
#    'rohrbach',
#    'stefmle',
#    'appear',
#    'cvpr2020',
#    'cvpr',
#    'cvpr2020',
#    'http']},
#  {'sentence': '"Our new work --\n"D3VO', 'words': ['new', 'work', 'd3vo']},
#  {'sentence': '"Our CVPR paper', 'words': ['cvpr', 'paper']},
#  {'sentence': '"CVPR 2020 paper decisions are now available, 1470 papers accepted',
#   'words': ['cvpr',
#    '2020',
#    'paper',
#    'decis',
#    'avail',
#    '1470',
#    'paper',
#    'accept']},
#  {'sentence': '"The code, pre-trained models, and datasets for #StarGANv2 is now available to everyone at https',
#   'words': ['code',
#    'pretrain',
#    'model',
#    'dataset',
#    'starganv2',
#    'avail',
#    'everyon',
#    'http']},
#  {'sentence': '"Research Internship at Niantic for PhD-level students.\n\nCome to London or Sunnyvale, do a research project with us and submit a paper to #CVPR or similar.\n\nhttps',
#   'words': ['research',
#    'internship',
#    'niantic',
#    'phdlevel',
#    'student',
#    'come',
#    'london',
#    'sunnyval',
#    'research',
#    'project',
#    'us',
#    'submit',
#    'paper',
#    'cvpr',
#    'similar',
#    'http']},
#  {'sentence': '"AI makes blurry faces look 64 times sharper https',
#   'words': ['ai',
#    'make',
#    'blurri',
#    'face',
#    'look',
#    '64',
#    'time',
#    'sharper',
#    'http']},
#  {'sentence': '"Definitely one of my favorite #CVPR presentations so far',
#   'words': ['definit', 'one', 'favorit', 'cvpr', 'present', 'far']},
#  {'sentence': '"#Deep Learning Based Antenna Selection for Channel Extrapolation in FDD Massive MIMO. (arXiv',
#   'words': ['deep',
#    'learn',
#    'base',
#    'antenna',
#    'select',
#    'channel',
#    'extrapol',
#    'fdd',
#    'massiv',
#    'mimo',
#    'arxiv']},
#  {'sentence': '"Im honored to share the 2020 Longuet-Higgins prize with @DeqingSun and Stefan Roth. It is given at #CVPR2020 for work from #CVPR 2010 that has withstood the test of time. Ive written a blog post about the secrets behind The Secrets of Optical Flow',
#   'words': ['im',
#    'honor',
#    'share',
#    '2020',
#    'longuethiggin',
#    'prize',
#    'deqingsun',
#    'stefan',
#    'roth',
#    'given',
#    'cvpr2020',
#    'work',
#    'cvpr',
#    '2010',
#    'withstood',
#    'test',
#    'time',
#    'ive',
#    'written',
#    'blog',
#    'post',
#    'secret',
#    'behind',
#    'secret',
#    'optic',
#    'flow']},
#  {'sentence': '"#NASA taps #Nvidia #GPUs to predict #solar #flares with cutting-edge #deep #learning https',
#   'words': ['nasa',
#    'tap',
#    'nvidia',
#    'gpu',
#    'predict',
#    'solar',
#    'flare',
#    'cuttingedg',
#    'deep',
#    'learn',
#    'http']},
#  {'sentence': '"A Detection of Informal Abbreviations from Free Text #Medical Notes Using #Deep Learning. Read full info at https',
#   'words': ['detect',
#    'inform',
#    'abbrevi',
#    'free',
#    'text',
#    'medic',
#    'note',
#    'use',
#    'deep',
#    'learn',
#    'read',
#    'full',
#    'info',
#    'http']},
#  {'sentence': '"Intel engineers helps develop #Deep-learning pipeline on #Xeon processors, aiming to expand #scalability & #performance. #IAmIntel https',
#   'words': ['intel',
#    'engin',
#    'help',
#    'develop',
#    'deeplearn',
#    'pipelin',
#    'xeon',
#    'processor',
#    'aim',
#    'expand',
#    'scalabl',
#    'perform',
#    'iamintel',
#    'http']},
#  {'sentence': '"#Newpaper [Article] Semi-Supervised Adversarial Variational Autoencoder\n\nhttps',
#   'words': ['newpap',
#    'articl',
#    'semisupervis',
#    'adversari',
#    'variat',
#    'autoencod',
#    'http']},
#  {'sentence': '"Five Successful AI and ML Use Cases In Manufacturing https',
#   'words': ['five',
#    'success',
#    'ai',
#    'ml',
#    'use',
#    'case',
#    'manufactur',
#    'http']},
#  {'sentence': '"Face Recognition with Deep Learning #data #science #deep #learning #python https',
#   'words': ['face',
#    'recognit',
#    'deep',
#    'learn',
#    'data',
#    'scienc',
#    'deep',
#    'learn',
#    'python',
#    'http']},
#  {'sentence': '"Learning is one of our favorite things about fly fishing!  Always something new to learn about the water we fish, the species we fish for, or us as fly fishers. #deep https',
#   'words': ['learn',
#    'one',
#    'favorit',
#    'thing',
#    'fli',
#    'fish',
#    'alway',
#    'someth',
#    'new',
#    'learn',
#    'water',
#    'fish',
#    'speci',
#    'fish',
#    'us',
#    'fli',
#    'fisher',
#    'deep',
#    'http']},
#  {'sentence': '"Computer Vision', 'words': ['comput', 'vision']},
#  {'sentence': '"Image Data Prep for Deep Learning Model #data #science #deep #learning #python https',
#   'words': ['imag',
#    'data',
#    'prep',
#    'deep',
#    'learn',
#    'model',
#    'data',
#    'scienc',
#    'deep',
#    'learn',
#    'python',
#    'http']},
#  {'sentence': '"#Deep Learning in Mapping for Autonomous Driving  #DataScience  #DataVisualization #DataAnalytics #DataFam https',
#   'words': ['deep',
#    'learn',
#    'map',
#    'autonom',
#    'drive',
#    'datasci',
#    'datavisu',
#    'dataanalyt',
#    'datafam',
#    'http']},
#  {'sentence': '"#camvid should be a toy example for #deep #learning in #semantic #segmentation ... I will give the #dataset to the public. I have searched the internet extensively to gather it. Soon I will write about it in my web page and give the @GoogleColab code for it."',
#   'words': ['camvid',
#    'toy',
#    'exampl',
#    'deep',
#    'learn',
#    'semant',
#    'segment',
#    'give',
#    'dataset',
#    'public',
#    'search',
#    'internet',
#    'extens',
#    'gather',
#    'soon',
#    'write',
#    'web',
#    'page',
#    'give',
#    'googlecolab',
#    'code']},
#  {'sentence': '"#Vacancy tenure-track assistant #professor in #computer #vision and #deep #learning at Atlas lab at University of #Amsterdam, a collaboration with TomTom. https',
#   'words': ['vacanc',
#    'tenuretrack',
#    'assist',
#    'professor',
#    'comput',
#    'vision',
#    'deep',
#    'learn',
#    'atla',
#    'lab',
#    'univers',
#    'amsterdam',
#    'collabor',
#    'tomtom',
#    'http']},
#  {'sentence': '"#Deep #learning AI model compression - Catering to the #edge https',
#   'words': ['deep',
#    'learn',
#    'ai',
#    'model',
#    'compress',
#    'cater',
#    'edg',
#    'http']},
#  {'sentence': '"Data Scientist - Leader #MA #Jobs #Data #Scientist #Science #Leader #AI #algorithms #deep #machine #learning #Python https',
#   'words': ['data',
#    'scientist',
#    'leader',
#    'ma',
#    'job',
#    'data',
#    'scientist',
#    'scienc',
#    'leader',
#    'ai',
#    'algorithm',
#    'deep',
#    'machin',
#    'learn',
#    'python',
#    'http']},
#  {'sentence': '"Our manuscript provides a summary of current techniques in #3Dprinting, #computational #modeling and #deep #learning in structural heart disease for improved therapy planning. #cardiotwitter https',
#   'words': ['manuscript',
#    'provid',
#    'summari',
#    'current',
#    'techniqu',
#    '3dprint',
#    'comput',
#    'model',
#    'deep',
#    'learn',
#    'structur',
#    'heart',
#    'diseas',
#    'improv',
#    'therapi',
#    'plan',
#    'cardiotwitt',
#    'http']},
#  {'sentence': '"SPARKLES OF THE SEASON - Four people rediscover the magic of Christmas, with a New Years surprise https',
#   'words': ['sparkl',
#    'season',
#    'four',
#    'peopl',
#    'rediscov',
#    'magic',
#    'christma',
#    'new',
#    'year',
#    'surpris',
#    'http']},
#  {'sentence': '" [Perspectives] An activist history of drug shortages and its silos  https',
#   'words': ['perspect',
#    'activist',
#    'histori',
#    'drug',
#    'shortag',
#    'silo',
#    'http']},
#  {'sentence': '"#49568__2__\n   ..\nunited we stand divided we fall..\nrise, join stand together and raise your voice... \n#medical #training #49568__2__\n#medicalkarwao #joiningdoo\n@myogiadityanath @dgpup @Uppolice @UPGovt"',
#   'words': ['495682',
#    'unit',
#    'stand',
#    'divid',
#    'fall',
#    'rise',
#    'join',
#    'stand',
#    'togeth',
#    'rais',
#    'voic',
#    'medic',
#    'train',
#    '495682',
#    'medicalkarwao',
#    'joiningdoo',
#    'myogiadityanath',
#    'dgpup',
#    'uppolic',
#    'upgovt']},
#  {'sentence': '"7Th #international Multidisciplinary #Congress on Good #Medical #Research. \nPlease join us! Visit our website. https',
#   'words': ['7th',
#    'intern',
#    'multidisciplinari',
#    'congress',
#    'good',
#    'medic',
#    'research',
#    'pleas',
#    'join',
#    'us',
#    'visit',
#    'websit',
#    'http']},
#  {'sentence': '"Students Are VIP \n\nDon\'t forget to share with us Your photos by sending thim DM or using our Hashtag #iamdarscruber \n\n#medicine #doctor #medical #health #covid #healthcare #nurse #medstudent #doctors #surgery https',
#   'words': ['student',
#    'vip',
#    'dont',
#    'forget',
#    'share',
#    'us',
#    'photo',
#    'send',
#    'thim',
#    'dm',
#    'use',
#    'hashtag',
#    'iamdarscrub',
#    'medicin',
#    'doctor',
#    'medic',
#    'health',
#    'covid',
#    'healthcar',
#    'nurs',
#    'medstud',
#    'doctor',
#    'surgeri',
#    'http']},
#  {'sentence': '" [Articles] Mifepristone and misoprostol versus misoprostol alone for the management of missed miscarriage (MifeMiso)',
#   'words': ['articl',
#    'mifepriston',
#    'misoprostol',
#    'versu',
#    'misoprostol',
#    'alon',
#    'manag',
#    'miss',
#    'miscarriag',
#    'mifemiso']},
#  {'sentence': '" Puddin just shouldin b thru bars! Hes just a baby! Pls RT him! Puddin shld bmuddin w/a boy to play with &a cozy 2sleep on! #medical #pledgesneeded @pearl_ober @hayley_Core_V @unicorndreams99 @sherian_holt @mgellis @Stacey5899 @MimisMemphisPet @TherealBethO https',
#   'words': ['puddin',
#    'shouldin',
#    'b',
#    'thru',
#    'bar',
#    'he',
#    'babi',
#    'pl',
#    'rt',
#    'puddin',
#    'shld',
#    'bmuddin',
#    'wa',
#    'boy',
#    'play',
#    'cozi',
#    '2sleep',
#    'medic',
#    'pledgesneed',
#    'pearlob',
#    'hayleycorev',
#    'unicorndreams99',
#    'sherianholt',
#    'mgelli',
#    'stacey5899',
#    'mimismemphispet',
#    'therealbetho',
#    'http']},
#  {'sentence': '"Insomnia identified as a new risk factor for type 2 diabetes. #Insomnia #Diabetes #Health #Medical #    \nhttps',
#   'words': ['insomnia',
#    'identifi',
#    'new',
#    'risk',
#    'factor',
#    'type',
#    '2',
#    'diabet',
#    'insomnia',
#    'diabet',
#    'health',
#    'medic',
#    'http']},
#  {'sentence': '"We\'ll help you get your #medicalmarijuana card! Visit us at https',
#   'words': ['well',
#    'help',
#    'get',
#    'medicalmarijuana',
#    'card',
#    'visit',
#    'us',
#    'http']},
#  {'sentence': '" \n\n#IndianArmy extends help and #Medical assistance to stranded #Chinese citizens at the India - China Border of #NorthSikkim at altitude of 17,500 feet under extreme climatic conditions. \n\nFor #IndianArmy #Humanity is foremost\n\n#HumanValues\n#IndianArmy\n#NationFirst https',
#   'words': ['indianarmi',
#    'extend',
#    'help',
#    'medic',
#    'assist',
#    'strand',
#    'chines',
#    'citizen',
#    'india',
#    'china',
#    'border',
#    'northsikkim',
#    'altitud',
#    '17500',
#    'feet',
#    'extrem',
#    'climat',
#    'condit',
#    'indianarmi',
#    'human',
#    'foremost',
#    'humanvalu',
#    'indianarmi',
#    'nationfirst',
#    'http']},
#  {'sentence': '" [Obituary] Peter Byass  https',
#   'words': ['obituari', 'peter', 'byass', 'http']},
#  {'sentence': '"Is she in love with hockey, fame, or him? BEYOND THE FACE-OFF\nhttps',
#   'words': ['love', 'hockey', 'fame', 'beyond', 'faceoff', 'http']},
#  {'sentence': '"Gika Health will provide fundamental #medical care and cutting-edge #medicine under different brands. Treat a wide range of #health issues, taking a personal touch and utilizing highly specialized and up-to-date research."',
#   'words': ['gika',
#    'health',
#    'provid',
#    'fundament',
#    'medic',
#    'care',
#    'cuttingedg',
#    'medicin',
#    'differ',
#    'brand',
#    'treat',
#    'wide',
#    'rang',
#    'health',
#    'issu',
#    'take',
#    'person',
#    'touch',
#    'util',
#    'highli',
#    'special',
#    'uptod',
#    'research']},
#  {'sentence': '"coming soon ! #apple #health #medical #science # "',
#   'words': ['come', 'soon', 'appl', 'health', 'medic', 'scienc']},
#  {'sentence': '"Worlds First Portable #MRI Machine Can Be Rolled Up To A Patient\'s Bedside. #MachineLearning #MedicalTech #Tech #Technology #Medical #MedicalImaging #Health # \nhttps',
#   'words': ['world',
#    'first',
#    'portabl',
#    'mri',
#    'machin',
#    'roll',
#    'patient',
#    'bedsid',
#    'machinelearn',
#    'medicaltech',
#    'tech',
#    'technolog',
#    'medic',
#    'medicalimag',
#    'health',
#    'http']},
#  {'sentence': '"Glucose Control Is difficult For Teens To Maintain.\n#Diabetes #Pediatrics #Health #Teens #Medical #  \nhttps',
#   'words': ['glucos',
#    'control',
#    'difficult',
#    'teen',
#    'maintain',
#    'diabet',
#    'pediatr',
#    'health',
#    'teen',
#    'medic',
#    'http']},
#  {'sentence': '"Most effective way for me to study origins and insertions - definitely a visual and tactile learner! \n\nHow do other #anatomy or #medical students do this effectively? Any tips?\n\n#anatomists @OpenAcademics @AcademicChatter #AcademicTwitter #AcademicChatter https',
#   'words': ['effect',
#    'way',
#    'studi',
#    'origin',
#    'insert',
#    'definit',
#    'visual',
#    'tactil',
#    'learner',
#    'anatomi',
#    'medic',
#    'student',
#    'effect',
#    'tip',
#    'anatomist',
#    'openacadem',
#    'academicchatt',
#    'academictwitt',
#    'academicchatt',
#    'http']},
#  {'sentence': '"We want new medicine faster, safer and smarter. \n\nhttps',
#   'words': ['want', 'new', 'medicin', 'faster', 'safer', 'smarter', 'http']},
#  {'sentence': '"Looking at some old #research papers and #medical #illustrations. #Parotid surgery is the perfect combo of intricate operative technique, aesthetic, oncology, and recon.  Plus I love the way the facial nerve looks! #surgery #Ent #AllDay #purpose @MayoClinicENT @MayoClinic https',
#   'words': ['look',
#    'old',
#    'research',
#    'paper',
#    'medic',
#    'illustr',
#    'parotid',
#    'surgeri',
#    'perfect',
#    'combo',
#    'intric',
#    'oper',
#    'techniqu',
#    'aesthet',
#    'oncolog',
#    'recon',
#    'plu',
#    'love',
#    'way',
#    'facial',
#    'nerv',
#    'look',
#    'surgeri',
#    'ent',
#    'allday',
#    'purpos',
#    'mayoclinic',
#    'mayoclin',
#    'http']},
#  {'sentence': '"Analytical Model of #Electron Density and Its #Machine Learning Inference \nhttps',
#   'words': ['analyt',
#    'model',
#    'electron',
#    'densiti',
#    'machin',
#    'learn',
#    'infer',
#    'http']},
#  {'sentence': '"High End Photoshop Portrait Retouch\nMy Services',
#   'words': ['high', 'end', 'photoshop', 'portrait', 'retouch', 'servic']},
#  {'sentence': '"Stephen Richards.- #quote #image via https',
#   'words': ['stephen', 'richard', 'quot', 'imag', 'via', 'http']},
#  {'sentence': '"Sacramento Photographers #SPG #WPC 372 Winner Vince Brashear. Theme "Bicolored Item"\nhttps',
#   'words': ['sacramento',
#    'photograph',
#    'spg',
#    'wpc',
#    '372',
#    'winner',
#    'vinc',
#    'brashear',
#    'theme',
#    'bicolor',
#    'item',
#    'http']},
#  {'sentence': '"NBA', 'words': ['nba']},
#  {'sentence': '"Buddha.- #quote #image Via https',
#   'words': ['buddha', 'quot', 'imag', 'via', 'http']},
#  {'sentence': '"Robert Green Ingersoll.- #quote #image Via https',
#   'words': ['robert', 'green', 'ingersol', 'quot', 'imag', 'via', 'http']},
#  {'sentence': '"When I make my art... #thirdeye #artist #present #past #future #selfie #portrait #edited #image #self #alchemy #passion #creator #5d https',
#   'words': ['make',
#    'art',
#    'thirdey',
#    'artist',
#    'present',
#    'past',
#    'futur',
#    'selfi',
#    'portrait',
#    'edit',
#    'imag',
#    'self',
#    'alchemi',
#    'passion',
#    'creator',
#    '5d',
#    'http']},
#  {'sentence': '"Steve Jobs.- #quote #image Via https',
#   'words': ['steve', 'job', 'quot', 'imag', 'via', 'http']},
#  {'sentence': '"#MadVerse prompt - greetings #inkslingers\n\nLet the images inspire your words or use',
#   'words': ['madvers',
#    'prompt',
#    'greet',
#    'inksling',
#    'let',
#    'imag',
#    'inspir',
#    'word',
#    'use']},
#  {'sentence': '"https', 'words': ['http']},
#  {'sentence': '"William Morris.- #quote #image Via https',
#   'words': ['william', 'morri', 'quot', 'imag', 'via', 'http']},
#  {'sentence': '"Dwayne Johnson "The Rock" #quote #image https',
#   'words': ['dwayn', 'johnson', 'rock', 'quot', 'imag', 'http']},
#  {'sentence': '"Chris Brogan.- #quote #image https',
#   'words': ['chri', 'brogan', 'quot', 'imag', 'http']},
#  {'sentence': '"Caterina Fake.- #quote #image https',
#   'words': ['caterina', 'fake', 'quot', 'imag', 'http']},
#  {'sentence': '"George Orwell.- #quote #image Via https',
#   'words': ['georg', 'orwel', 'quot', 'imag', 'via', 'http']},
#  {'sentence': '"Watch this tutorial for \nhttps',
#   'words': ['watch', 'tutori', 'http']},
#  {'sentence': '"How to Optimize your Image - https',
#   'words': ['optim', 'imag', 'http']},
#  {'sentence': '"J.K. Rowling #quote #image https',
#   'words': ['jk', 'rowl', 'quot', 'imag', 'http']},
#  {'sentence': '"Henry Adams.- #quote #image Via https',
#   'words': ['henri', 'adam', 'quot', 'imag', 'via', 'http']},
#  {'sentence': '"The Face in the Bush by John M Bailey. Walking along a trail in the Florida wetlands we came across this. Gulp! #Faces #image #photoart https',
#   'words': ['face',
#    'bush',
#    'john',
#    'm',
#    'bailey',
#    'walk',
#    'along',
#    'trail',
#    'florida',
#    'wetland',
#    'came',
#    'across',
#    'gulp',
#    'face',
#    'imag',
#    'photoart',
#    'http']}]

# %%
from bs4 import BeautifulSoup

# %%
f = open('hw1_iir_data/test1.xml','r',encoding="utf-8")

# %%
raw = f.read()

# %%
raw
# Out:
# '<?xml version="1.0" ?>\n<!DOCTYPE PubmedArticleSet PUBLIC "-//NLM//DTD PubMedArticle, 1st January 2019//EN" "https://dtd.nlm.nih.gov/ncbi/pubmed/out/pubmed_190101.dtd">\n<PubmedArticleSet>\n<PubmedArticle>\n    <MedlineCitation Status="Publisher" Owner="NLM">\n        <PMID Version="1">32950037</PMID>\n        <DateRevised>\n            <Year>2020</Year>\n            <Month>09</Month>\n            <Day>19</Day>\n        </DateRevised>\n        <Article PubModel="Print-Electronic">\n            <Journal>\n                <ISSN IssnType="Electronic">1754-4505</ISSN>\n                <JournalIssue CitedMedium="Internet">\n                    <PubDate>\n                        <Year>2020</Year>\n                        <Month>Sep</Month>\n                        <Day>19</Day>\n                    </PubDate>\n                </JournalIssue>\n                <Title>Special care in dentistry : official publication of the American Association of Hospital Dentists, the Academy of Dentistry f
# ...

# %%
soup = BeautifulSoup(raw, 'lxml')

# %%
soup.prettify()
# Out:
# '<?xml version="1.0" ?>\n<!DOCTYPE PubmedArticleSet PUBLIC "-//NLM//DTD PubMedArticle, 1st January 2019//EN" "https://dtd.nlm.nih.gov/ncbi/pubmed/out/pubmed_190101.dtd">\n<html>\n <body>\n  <pubmedarticleset>\n   <pubmedarticle>\n    <medlinecitation owner="NLM" status="Publisher">\n     <pmid version="1">\n      32950037\n     </pmid>\n     <daterevised>\n      <year>\n       2020\n      </year>\n      <month>\n       09\n      </month>\n      <day>\n       19\n      </day>\n     </daterevised>\n     <article pubmodel="Print-Electronic">\n      <journal>\n       <issn issntype="Electronic">\n        1754-4505\n       </issn>\n       <journalissue citedmedium="Internet">\n        <pubdate>\n         <year>\n          2020\n         </year>\n         <month>\n          Sep\n         </month>\n         <day>\n          19\n         </day>\n        </pubdate>\n       </journalissue>\n       <title>\n        Special care in dentistry : official publication of the American Association of 
# ...

# %%
soup
# Out:
# <?xml version="1.0" ?><!DOCTYPE PubmedArticleSet PUBLIC "-//NLM//DTD PubMedArticle, 1st January 2019//EN" "https://dtd.nlm.nih.gov/ncbi/pubmed/out/pubmed_190101.dtd">
# <html><body><pubmedarticleset>
# <pubmedarticle>
# <medlinecitation owner="NLM" status="Publisher">
# <pmid version="1">32950037</pmid>
# <daterevised>
# <year>2020</year>
# <month>09</month>
# <day>19</day>
# </daterevised>
# <article pubmodel="Print-Electronic">
# <journal>
# <issn issntype="Electronic">1754-4505</issn>
# <journalissue citedmedium="Internet">
# <pubdate>
# <year>2020</year>
# <month>Sep</month>
# <day>19</day>
# </pubdate>
# </journalissue>
# <title>Special care in dentistry : official publication of the American Association of Hospital Dentists, the Academy of Dentistry for the Handicapped, and the American Society for Geriatric Dentistry</title>
# <isoabbreviation>Spec Care Dentist</isoabbreviation>
# </journal>
# <articletitle>Dental care management during the COVID-19 outbreak.</articletitle>
# ...

# %%
Abstracts = soup.find_all('abstract')

# %%
Abstracts
# Out:
# [<abstract>
#  <abstracttext label="AIM" nlmcategory="OBJECTIVE">The level of preparedness of the healthcare system plays an important role in management of coronavirus disease 2019 (COVID-19). This study attempted to devise a comprehensive protocol regarding dental care during the COVID-19 outbreak.</abstracttext>
#  <abstracttext label="METHODS AND RESULT" nlmcategory="RESULTS">Embase, PubMed, and Google Scholar were searched until March 2020 for relevant papers. Sixteen English papers were enrolled to answer questions about procedures that are allowed to perform during the COVID-19 outbreak, patients who are in priority to receive dental care services, the conditions and necessities for patient admission, waiting room and operatory room, and personal protective equipment (PPE) that is necessary for dental clinicians and the office staff.</abstracttext>
# ...

# %% [markdown]
# # Show Here

# %%
for abst in Abstracts:
    AbstractText = abst.find_all('abstracttext')
    print('abstract')
    for i in AbstractText:
        if i.get('label') != None:
            print(i.get('label'))
        print(i.string, end='\n\n')
# Out:
# abstract
# AIM
# The level of preparedness of the healthcare system plays an important role in management of coronavirus disease 2019 (COVID-19). This study attempted to devise a comprehensive protocol regarding dental care during the COVID-19 outbreak.
#
# METHODS AND RESULT
# Embase, PubMed, and Google Scholar were searched until March 2020 for relevant papers. Sixteen English papers were enrolled to answer questions about procedures that are allowed to perform during the COVID-19 outbreak, patients who are in priority to receive dental care services, the conditions and necessities for patient admission, waiting room and operatory room, and personal protective equipment (PPE) that is necessary for dental clinicians and the office staff.
#
# CONCLUSION
# ...

# %%
import nltk

# %%
import string
#Show the punctuation
string.punctuation

# %%
s = []
w = []
all_words = []
for ab in Abstracts:
    _s = 0
    _w = 0
    print('==============================================')
    temp_all_words = []
    for i in ab.find_all('abstracttext'):
        temp = nltk.sent_tokenize(i.string)
        temp2 = (i.string).split()
        for k in temp2:
            temp_all_words.append(k)
        _s += len(temp)
        _w += len(temp2)
        for j in temp:
            print(j, end='\n\n')
    all_words.append(temp_all_words)
    s.append(_s)
    w.append(_w)
# Out:
# ...
# The level of preparedness of the healthcare system plays an important role in management of coronavirus disease 2019 (COVID-19).
#
# This study attempted to devise a comprehensive protocol regarding dental care during the COVID-19 outbreak.
#
# Embase, PubMed, and Google Scholar were searched until March 2020 for relevant papers.
#
# Sixteen English papers were enrolled to answer questions about procedures that are allowed to perform during the COVID-19 outbreak, patients who are in priority to receive dental care services, the conditions and necessities for patient admission, waiting room and operatory room, and personal protective equipment (PPE) that is necessary for dental clinicians and the office staff.
#
# Dental treatment should be limited to patients with urgent or emergency situation.
#
# By screening questionnaires for COVID-19, patients are divided into three groups of (a) apparently healthy, (b) suspected for COVID-19, and (c) confirmed for COVID-19.
#
# ...

# %%
s
# Out:
# [8, 14, 9]

# %%
w
# Out:
# [206, 341, 208]

# %%
len(all_words)
# Out:
# 3

# %%
all_words
# Out:
# [['The',
#   'level',
#   'of',
#   'preparedness',
#   'of',
#   'the',
#   'healthcare',
#   'system',
#   'plays',
#   'an',
#   'important',
#   'role',
#   'in',
#   'management',
#   'of',
#   'coronavirus',
#   'disease',
#   '2019',
#   '(COVID-19).',
#   'This',
#   'study',
#   'attempted',
#   'to',
#   'devise',
#   'a',
#   'comprehensive',
#   'protocol',
#   'regarding',
#   'dental',
#   'care',
#   'during',
#   'the',
#   'COVID-19',
#   'outbreak.',
#   'Embase,',
#   'PubMed,',
#   'and',
#   'Google',
#   'Scholar',
#   'were',
#   'searched',
#   'until',
#   'March',
#   '2020',
#   'for',
#   'relevant',
#   'papers.',
#   'Sixteen',
#   'English',
#   'papers',
#   'were',
#   'enrolled',
#   'to',
#   'answer',
#   'questions',
#   'about',
#   'procedures',
#   'that',
#   'are',
#   'allowed',
#   'to',
#   'perform',
#   'during',
#   'the',
#   'COVID-19',
#   'outbreak,',
#   'patients',
#   'who',
#   'are',
#   'in',
#   'priority',
#   'to',
# ...

# %%
en_titles = ['Mr.', 'Mrs.', 'Dr.', 'Prof.','Hon.']

new_all_words = []

for words in all_words:
    for i in range(len(words)):
        if words[i] in en_titles:
            continue
        elif len(words[i])==2 and words[i][0].isupper():
            continue
        else:
            for j in string.punctuation:
                words[i] = words[i].replace(j, '')

    new_all_words.append([i for i in words if i != ""])

# %%
new_all_words
# Out:
# [['The',
#   'level',
#   'of',
#   'preparedness',
#   'of',
#   'the',
#   'healthcare',
#   'system',
#   'plays',
#   'an',
#   'important',
#   'role',
#   'in',
#   'management',
#   'of',
#   'coronavirus',
#   'disease',
#   '2019',
#   'COVID19',
#   'This',
#   'study',
#   'attempted',
#   'to',
#   'devise',
#   'a',
#   'comprehensive',
#   'protocol',
#   'regarding',
#   'dental',
#   'care',
#   'during',
#   'the',
#   'COVID19',
#   'outbreak',
#   'Embase',
#   'PubMed',
#   'and',
#   'Google',
#   'Scholar',
#   'were',
#   'searched',
#   'until',
#   'March',
#   '2020',
#   'for',
#   'relevant',
#   'papers',
#   'Sixteen',
#   'English',
#   'papers',
#   'were',
#   'enrolled',
#   'to',
#   'answer',
#   'questions',
#   'about',
#   'procedures',
#   'that',
#   'are',
#   'allowed',
#   'to',
#   'perform',
#   'during',
#   'the',
#   'COVID19',
#   'outbreak',
#   'patients',
#   'who',
#   'are',
#   'in',
#   'priority',
#   'to',
#   'receive',
# ...

# %%
for i in new_all_words:
    print(len(i))
# Out:
# 179
# 267
# 190

# %%
179+267+190
# Out:
# 636
